# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Idsproject_dataset.csv")

# %%
df=df.sample(800)

# %%
df.head()
df
# Out:
#                                                     name  seller offerType  \
# 22280                         Opel_Meriva_1.7_CDTI_Cosmo  privat   Angebot
# 4770                        Toyota_Yaris_TÜV_bis_11.2017  privat   Angebot
# 9987                                        Opel_Astra_H  privat   Angebot
# 21512                       Volvo_xc70_D5_Vollauslastung  privat   Angebot
# 2289        Volkswagen_Sharan_1.9_TDI_Comfortline_Family  privat   Angebot
# 59437                             Renault_megane_classic  privat   Angebot
# 7882    Peugeot_206_CC_2.0_16_V_Servicegepflegtes_cabrio  privat   Angebot
# 11868  Fiat_Freemont_2.0_Multijet_16V_DPF_Automatik_A...  privat   Angebot
# 26908                                  Golf_4_/_4_tuerig  privat   Angebot
# 23944                          Tuev_neu_ahk!_Auch_tausch  privat   Angebot
# 19189                           Audi_A4_1.9_TDI_ohne_DPF  privat   Angebot
# ...

# %%
df["vehicleType"].fillna(method='ffill', inplace = True)

# %%
df["seller"].fillna(method='ffill', inplace = True)

# %%
df["abtest"].fillna(method='ffill', inplace = True)

# %%
df["gearbox"].fillna(method='ffill', inplace = True)

# %%
df["model"].fillna(method='ffill', inplace = True)

# %%
df["fuelType"].fillna(method='ffill', inplace = True)

# %%
df["brand"].fillna(method='ffill', inplace = True)

# %%
df["notRepairedDamage"].fillna(method='ffill', inplace = True)

# %%
df.head()
df.isnull().sum()
# Out:
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# postalCode             0
# dtype: int64

# %%
df["price"].fillna(df["price"].mean(), inplace = True)

# %%
df["yearOfRegistration"].fillna(df["yearOfRegistration"].mean(), inplace = True)

# %%
df["powerPS"].fillna(df["powerPS"].mean(), inplace = True)

# %%
df["kilometer"].fillna(df["kilometer"].mean(), inplace = True)

# %%
df["monthOfRegistration"].fillna(df["monthOfRegistration"].mean(), inplace = True)

# %%
df["postalCode"].fillna(df["postalCode"].mean(), inplace = True)

# %%
df
# Out:
#                                                     name  seller offerType  \
# 24785  BMW_525d_E61_TOURING_AUT._S_GRAU_MET._TÜV06/17...  privat   Angebot
# 51204               Renault_Scenic_1.9_dCi_FAP_Exception  privat   Angebot
# 3871   Merceded_Benz_W211_E500_Avantgarde_Vollausstat...  privat   Angebot
# 38100         Volkswagen_Caravelle_C_255_541_H_Zulassung  privat   Angebot
# 13021                                 Peugeot_307_SW_110  privat   Angebot
# 42665                         BMW_316i_Zylinder_gerissen  privat   Angebot
# 44498  Volkswagen_Passat_Variant_2.0_TDI_DSG_BlueMoti...  privat   Angebot
# 18711                       Subaru_Forester_2.0D_Comfort  privat   Angebot
# 20481  Audi_A7_2.8_FSI_quattro_S_tronic___erst_24800k...  privat   Angebot
# 35972                     Skoda_Roomster_1.4_16V_Comfort  privat   Angebot
# 63786  Volkswagen_Golf_Variant_1.9_TDI_Special__Schec...  privat   Angebot
# ...

# %%
for i in range(len(np.array(df['price']))):
    df['price'].iloc[i]=((df['price'].iloc[i] - df['price'].mean()))/(df['price'].std())
# Out:
# F:\Anaconda\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
for i in range(len(np.array(df['powerPS']))):
    df['powerPS'].iloc[i]=((df['powerPS'].iloc[i] - df['powerPS'].mean()))/(df['powerPS'].std())
# Out:
# F:\Anaconda\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.head()
# Out:
#                                                     name  seller offerType  \
# 24785  BMW_525d_E61_TOURING_AUT._S_GRAU_MET._TÜV06/17...  privat   Angebot
# 51204               Renault_Scenic_1.9_dCi_FAP_Exception  privat   Angebot
# 3871   Merceded_Benz_W211_E500_Avantgarde_Vollausstat...  privat   Angebot
# 38100         Volkswagen_Caravelle_C_255_541_H_Zulassung  privat   Angebot
# 13021                                 Peugeot_307_SW_110  privat   Angebot
#
#           price   abtest vehicleType  yearOfRegistration    gearbox   powerPS  \
# 24785  0.306554     test       kombi                2004  automatik  0.219995
# 51204 -0.382115     test         bus                2006    manuell  0.050692
# 3871   0.694870     test   limousine                2003  automatik  0.698340
# 38100  0.008219  control         bus                1981    manuell -0.246836
# 13021 -0.417443     test       kombi                2003    manuell -0.028412
#
# ...

# %%
for i in range(len(np.array(df['kilometer']))):
    df['kilometer'].iloc[i]=(df['kilometer'].iloc[i] - df['kilometer'].mean())
# Out:
# F:\Anaconda\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['powerPS'],density=True,bins=30)
# Out:
# (array([0.4390908 , 0.30078391, 0.15173474, 0.07788155, 0.03356963,
#         0.01611342, 0.01342785, 0.01208507, 0.00402836, 0.0093995 ,
#         0.00268557, 0.00134279, 0.00134279, 0.        , 0.00268557,
#         0.00134279, 0.00134279, 0.        , 0.        , 0.        ,
#         0.00134279, 0.        , 0.00134279, 0.        , 0.        ,
#         0.        , 0.00134279, 0.        , 0.        , 0.00134279]),
#  array([-0.7527132 ,  0.17818766,  1.10908851,  2.03998937,  2.97089023,
#          3.90179108,  4.83269194,  5.7635928 ,  6.69449365,  7.62539451,
#          8.55629537,  9.48719623, 10.41809708, 11.34899794, 12.2798988 ,
#         13.21079965, 14.14170051, 15.07260137, 16.00350222, 16.93440308,
#         17.86530394, 18.79620479, 19.72710565, 20.65800651, 21.58890736,
#         22.51980822, 23.45070908, 24.38160993, 25.31251079, 26.24341165,
#         27.1743125 ]),
#  <a list of 30 Patch objects>)

# %%
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(16,8))
sns.countplot(y='vehicleType',data=df)
plt.show()

# %%
df['kilometer'].plot.line()

# %%
df['powerPS'].plot.box()

# %%
sns.boxplot(x='fuelType', y='kilometer', data=df)

# %%
g = sns.kdeplot(df.powerPS, color="Red", shade = True)
g.set_xlabel("powerPS")
g.set_ylabel("frequency")
plt.title('Distribution of powerPS',size = 20)
# Out:
# Text(0.5,1,'Distribution of powerPS')

# %%
import math
y1=np.array(df['powerPS'])
z1=math.sqrt(y1.var())
k=y1.min()
for i in range(800):
    y1[i]=(y1[i]-k)/(z1)

# %%
g = sns.kdeplot(df.price, color="Red", shade = True)
g.set_xlabel("price")
g.set_ylabel("frequency")
plt.title('Distribution of price',size = 20)
# Out:
# Text(0.5,1,'Distribution of price')

# %%
df['powerPS'].plot.box()

# %%
y = df['powerPS']
size=800
removed_outliers = y.between(y.quantile(.25), y.quantile(.90))

# %%
print(str(y[removed_outliers].size) + "/" + str(size) + " data points remain.") 

y[removed_outliers].plot().get_figure()
# Out:
# 520/800 data points remain.

# %%
y[removed_outliers].plot.box()

# %%
plt.hist(y[removed_outliers],density=True)
# Out:
# (array([1.18460679, 0.58237652, 0.29780618, 0.28457035, 0.27795243,
#         0.21177328, 0.22500911, 0.12574039, 0.1323583 , 0.11912247]),
#  array([-0.01938706,  0.27119946,  0.56178599,  0.85237251,  1.14295904,
#          1.43354556,  1.72413209,  2.01471861,  2.30530514,  2.59589166,
#          2.88647819]),
#  <a list of 10 Patch objects>)

# %%
    mu, sigma=df['powerPS'].mean(),df['powerPS'].std()
    z=(df['powerPS']-mu)/sigma

# %%
mu=0
sigma=1

# %%
sample_test = df.sample(400)

# %% [markdown]
# sample

# %% [markdown]
# sample_test

# %%
sample_test
# Out:
#                                                     name  seller offerType  \
# 48307  Ideales_Pendler__oder_Zweitfahrzeug_Chevrolet_...  privat   Angebot
# 31471                               Mercedes_Benz_c__220  privat   Angebot
# 555                                 Mercedes_Benz_SL_380  privat   Angebot
# 57079  BMW_318d_DPF_Touring__6_Gang__Klimaautom._Xeno...  privat   Angebot
# 25272                                   BMW_316i_touring  privat   Angebot
# 52746  Golf_4_1.8_Turbo_GTI_mit_Chip_und_Blow_Off_Ven...  privat   Angebot
# 29188                                           BMW_318i  privat   Angebot
# 29526                                    Vw_passat_Kombi  privat   Angebot
# 46254                               Dodge_hotrod_Pick_Up  privat   Angebot
# 8651                         Audi_A3_Attraction_1.4_TFSI  privat   Angebot
# 14892                             BMW_e91_330d_//M_PAKET  privat   Angebot
# ...

# %%
df2 = pd.read_csv("Idsproject_dataset.csv")
sample = pd.DataFrame(df2)

# %%
test_specimens = ['kleinwagen','limousine']
sample_test = sample[sample['vehicleType'].isin(test_specimens)]

# %%
sample_test
# Out:
#                                                     name  seller offerType  \
# 3                                     GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                         Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5      BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 7                           VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# 9      VW_Golf_4_5_tuerig_zu_verkaufen_mit_Anhaengerk...  privat   Angebot
# 10                                     Mazda_3_1.6_Sport  privat   Angebot
# 15                          KA_Lufthansa_Edition_450€_VB  privat   Angebot
# 17                           Renault_Twingo_1.2_16V_Aut.  privat   Angebot
# 21     BMW_530i_TÜV_7/17_Scheckheftgepflegt_sehr_gute...  privat   Angebot
# 23                                          Stadtflitzer  privat   Angebot
# 24                            MERCEDES_200E__TÜV_04/2016  privat   Angebot
# ...

# %%
power_lim = 0
power_klein = 0
count_lim = 0
count_klein = 0
var_lim=0
var_klein=0

for i in range(len(df2)):
    if(df2['vehicleType'].iloc[i]=='kleinwagen'):
        power_klein += df2['powerPS'].iloc[i]
        count_klein +=1
    else:
        power_lim += df2['powerPS'].iloc[i]
        count_lim +=1
        
mean_lim = power_lim/count_lim
mean_klein = power_klein/count_klein

for i in range(len(df2)):
    if(df2['vehicleType'].iloc[i]=='kleinwagen'):
        var_klein += (df2['powerPS'].iloc[i]-mean_klein)**2
    else:
        var_lim += (df2['powerPS'].iloc[i]-mean_lim)**2
